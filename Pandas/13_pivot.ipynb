# %%
import pandas as pd

# read csv file
gdp_df = pd.read_csv("F:\Python_Programming_Learning\Pandas\data\gdp.csv", encoding='latin-1')
gdp_df.head()
# Out:
#    unid wbid      country  year        SES      gdppc  yrseduc  popshare
# 0     4  AFG  Afghanistan  1970   3.474212  709.00000      NaN  0.003097
# 1     4  AFG  Afghanistan  1920  26.968016  731.75677      NaN  0.003245
# 2     4  AFG  Afghanistan  1990   1.269530  604.00000      NaN  0.002347
# 3     4  AFG  Afghanistan  1960  15.763076  739.00000      NaN  0.003039
# 4     4  AFG  Afghanistan  2000   2.061114  565.00000      NaN  0.003309

# %%
# reshape dataframe using pivot table
year_wise_gdp_df = gdp_df.pivot(index='year', columns='country', values='gdppc').round(2)
year_wise_gdp_df
# Out:
# country  Afghanistan  Albania   Algeria   Angola  Argentina  Armenia  \
# year
# 1880          585.47   522.00    819.19   533.67    1731.50  1041.00
# 1890          635.93   598.00    923.37   567.33    2152.00  1139.00
# 1900          686.40   685.00   1027.56   601.00    2756.00  1237.00
# 1910          736.86   780.00   1131.74   628.69    3822.00  1430.08
# 1920          731.76   861.31   1201.22   682.63    3473.00  1432.93
# 1930          702.84   929.57   1255.81   747.81    4080.00  1448.00
# 1940          673.92   965.29   1310.41   813.00    4161.00  2144.00
# 1950          645.00  1001.00   1365.00  1052.00    4987.00  2841.00
# 1960          739.00  1451.00   2088.00  1253.00    5559.00  3945.00
# 1970          709.00  2004.00   2249.00  1768.00    7302.00  5575.00
# 1980          690.00  2347.00   3152.00   961.00    8206.00  6116.59
# 1990          604.00  4557.41  10238.88  4806.43   10833.50  3735.54
# ...

# %%
# get year wise gdp per capita for a specific
year_wise_gdp_df['Bangladesh'].round(2)
# Out:
# year
# 1880     566.67
# 1890     587.33
# 1900     608.00
# 1910     661.85
# 1920     651.89
# 1930     614.59
# 1940     577.30
# 1950     540.00
# 1960     545.00
# 1970     630.00
# 1980     549.00
# 1990    1290.43
# 2000    1645.72
# 2010    2451.31
# Name: Bangladesh, dtype: float64
