# %%
import pandas as pd

# read data from csv file
raw_population_df = pd.read_csv('F:\Python_Programming_Learning\Pandas\Data\population_total.csv')
raw_population_df.head()
# Out:
#   country    year    population
# 0   China  2020.0  1.439324e+09
# 1   China  2019.0  1.433784e+09
# 2   China  2018.0  1.427648e+09
# 3   China  2017.0  1.421022e+09
# 4   China  2016.0  1.414049e+09

# %%
# get shape
raw_population_df.shape
# Out:
# (4185, 3)

# %%
# get size
raw_population_df.size
# Out:
# 12555

# %%
# clean data by droping null values
processed_population_df = raw_population_df.dropna()
processed_population_df
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4178 rows x 3 columns]

# %%
# get process data's shape
processed_population_df.shape
# Out:
# (4178, 3)

# %%
# get process data's size
processed_population_df.shape
# Out:
# (4178, 3)

# %%
# make pivot by using proccessed data
population_pivot = processed_population_df.pivot(index='year', columns='country', values='population')
population_pivot
# Out:
# country  Afghanistan    Albania     Algeria  American Samoa  Andorra  \
# year
# 1955.0     8270991.0  1419994.0   9774283.0         19754.0   9232.0
# 1960.0     8996973.0  1636090.0  11057863.0         20123.0  13411.0
# 1965.0     9956320.0  1896171.0  12550885.0         23672.0  18549.0
# 1970.0    11173642.0  2150707.0  14464985.0         27363.0  24276.0
# 1975.0    12689160.0  2411732.0  16607707.0         30052.0  30705.0
# 1980.0    13356511.0  2682690.0  19221665.0         32646.0  36067.0
# 1985.0    11938208.0  2969672.0  22431502.0         39519.0  44600.0
# 1990.0    12412308.0  3286073.0  25758869.0         47347.0  54509.0
# 1995.0    18110657.0  3112936.0  28757785.0         53161.0  63850.0
# 2000.0    20779953.0  3129243.0  31042235.0         57821.0  65390.0
# 2005.0    25654277.0  3086810.0  33149724.0         59562.0  78867.0
# 2010.0    29185507.0  2948023.0  35977455.0         56079.0  84449.0
# ...

# %%
# select some countries
selected_countries_pivot_df = population_pivot[ ['Afghanistan', 'Bangladesh', 'India', 'Pakistan', 'Indonesia', 'Iran', 'Brazil'] ]
selected_countries_pivot_df
# Out:
# country  Afghanistan   Bangladesh         India     Pakistan    Indonesia  \
# year
# 1955.0     8270991.0   42086301.0  4.098806e+08   40488030.0   77273425.0
# 1960.0     8996973.0   48013504.0  4.505477e+08   44988690.0   87751068.0
# 1965.0     9956320.0   55385112.0  4.991233e+08   50917975.0  100267062.0
# 1970.0    11173642.0   64232482.0  5.551898e+08   58142060.0  114793178.0
# 1975.0    12689160.0   70066301.0  6.231029e+08   66816877.0  130680727.0
# 1980.0    13356511.0   79639491.0  6.989528e+08   78054343.0  147447836.0
# 1985.0    11938208.0   90764183.0  7.843600e+08   92191510.0  164982451.0
# 1990.0    12412308.0  103171956.0  8.732778e+08  107647921.0  181413402.0
# 1995.0    18110657.0  115169930.0  9.639226e+08  123776839.0  196934260.0
# 2000.0    20779953.0  127657854.0  1.056576e+09  142343578.0  211513823.0
# 2005.0    25654277.0  139035505.0  1.147610e+09  160304008.0  226289470.0
# 2010.0    29185507.0  147575430.0  1.234281e+09  179424641.0  241834215.0
# ...

# %%
# visualize data with line plot
selected_countries_pivot_df.plot(kind='line', xlabel='year', ylabel='population (Billion)', title='Population data analysis (1960 - 2020)', figsize=(10,5))
# Out:
# <Axes: title={'center': 'Population data analysis (1960 - 2020)'}, xlabel='year', ylabel='population (Billion)'>

# %%
# select one year data only
selected_countries_pivot_df_for_year_2020 = selected_countries_pivot_df[selected_countries_pivot_df.index.isin([2020])]
selected_countries_pivot_df_for_year_2020
# Out:
# country  Afghanistan   Bangladesh         India     Pakistan    Indonesia  \
# year
# 2020.0    38928346.0  164689383.0  1.380004e+09  220892340.0  273523615.0
#
# country        Iran       Brazil
# year
# 2020.0   83992949.0  212559417.0

# %%
# transpose dataframe rows to cols or viseversa
selected_countries_pivot_df_for_year_2020 = selected_countries_pivot_df_for_year_2020.T
selected_countries_pivot_df_for_year_2020
# Out:
# year               2020.0
# country
# Afghanistan  3.892835e+07
# Bangladesh   1.646894e+08
# India        1.380004e+09
# Pakistan     2.208923e+08
# Indonesia    2.735236e+08
# Iran         8.399295e+07
# Brazil       2.125594e+08

# %%
# visualize data with bar chart
selected_countries_pivot_df_for_year_2020.plot(kind='bar', xlabel='country', ylabel='population (billion)', title='Population data analysis - 2020', figsize=(10, 5), color='red')
# Out:
# <Axes: title={'center': 'Population data analysis - 2020'}, xlabel='country', ylabel='population (billion)'>

# %%
# select data only for year 1960, 1980, 2000, 2020 of some countries
selected_years_pivot_df = selected_countries_pivot_df[selected_countries_pivot_df.index.isin([1960, 1980, 2000, 2020])].T
selected_years_pivot_df
# Out:
# year              1960.0       1980.0        2000.0        2020.0
# country
# Afghanistan    8996973.0   13356511.0  2.077995e+07  3.892835e+07
# Bangladesh    48013504.0   79639491.0  1.276579e+08  1.646894e+08
# India        450547679.0  698952844.0  1.056576e+09  1.380004e+09
# Pakistan      44988690.0   78054343.0  1.423436e+08  2.208923e+08
# Indonesia     87751068.0  147447836.0  2.115138e+08  2.735236e+08
# Iran          21906914.0   38650246.0  6.562340e+07  8.399295e+07
# Brazil        72179226.0  120694009.0  1.747903e+08  2.125594e+08

# %%
# visualize data with grouped bar chart
selected_years_pivot_df.plot(kind='bar', xlabel='country', ylabel='population (billion)', title='Population analysis', figsize=(10, 5))
# Out:
# <Axes: title={'center': 'Population analysis'}, xlabel='country', ylabel='population (billion)'>

# %%
# visualize data with pie chart
rename_2020_col_to_str = selected_countries_pivot_df_for_year_2020.rename(columns={2020: '2020'})
rename_2020_col_to_str.plot(kind='pie', y='2020', title='population in 2020 (%)')
# Out:
# <Axes: title={'center': 'population in 2020 (%)'}, ylabel='2020'>
