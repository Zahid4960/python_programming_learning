# %%
import pandas as pd

# read csv file
student_performance_df = pd.read_csv('F:\Python_Programming_Learning\Pandas\Data\students_performance.csv')
student_performance_df.head()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 25    male        group A             master's degree  free/reduced
# 61    male        group A            some high school  free/reduced
# 62    male        group A          associate's degree  free/reduced
# 72  female        group A          associate's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 3                     none          47             57             44
# 25                    none          73             74             72
# 61                    none          39             39             34
# 62                    none          62             61             55
# 72                    none          41             51             48

# %%
# sort by single column for number
student_performance_df.sort_values(by='math score')
student_performance_df.sort_values(by='math score', ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 458  female        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 962  female        group E          associate's degree      standard
# 916    male        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# sort by multiple coulmn for number
student_performance_df.sort_values(by=['math score', 'reading score'], ascending=False)
student_performance_df.head()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 25    male        group A             master's degree  free/reduced
# 61    male        group A            some high school  free/reduced
# 62    male        group A          associate's degree  free/reduced
# 72  female        group A          associate's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 3                     none          47             57             44
# 25                    none          73             74             72
# 61                    none          39             39             34
# 62                    none          62             61             55
# 72                    none          41             51             48

# %%
# sort by single column for string
student_performance_df.sort_values(by='race/ethnicity', ascending=False, key=lambda col:col.str.lower())
student_performance_df.head()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 25    male        group A             master's degree  free/reduced
# 61    male        group A            some high school  free/reduced
# 62    male        group A          associate's degree  free/reduced
# 72  female        group A          associate's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 3                     none          47             57             44
# 25                    none          73             74             72
# 61                    none          39             39             34
# 62                    none          62             61             55
# 72                    none          41             51             48

# %%
# sort by multiple column for string
student_performance_df.sort_values(by=['race/ethnicity', 'lunch'], inplace=True, key=lambda col:col.str.lower())
student_performance_df.head()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 25    male        group A             master's degree  free/reduced
# 61    male        group A            some high school  free/reduced
# 62    male        group A          associate's degree  free/reduced
# 72  female        group A          associate's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 3                     none          47             57             44
# 25                    none          73             74             72
# 61                    none          39             39             34
# 62                    none          62             61             55
# 72                    none          41             51             48
